# %% [markdown]
# ![image.png](attachment:image.png)
#
# Nvidia 면접 문제로 나왔었음

# %%
def conv(image,filter,threshold):
    #image_size = (n,n)
    #filte_size = (k,k) with k<<n
    #score가 threshold보다 높으면 해당자리에 output이 있다고 결과를 내고 없으면 그냥지나가야함
    image_height, image_width = len(image),len(image[0])
    filter_size = len(filter)
    result = [[0] * image_width for _ in range(image_height)]
    


    for n_1 in range(image_height):
        for n_2 in range(image_width):
            inner_product = 0
            mat = image[n_1:n_1+filter_size,n_2:n_2+filter_size]
            for k_1 in range(filter_size):
                for K_2 in range(len(filter_size[0])):
                    inner_product += image[n_1 + k_1]
